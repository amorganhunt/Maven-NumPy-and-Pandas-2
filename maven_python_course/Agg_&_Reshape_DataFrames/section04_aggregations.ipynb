# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Assignment 1: Groupby
#
# Can you return a table containing the top 10 stores by total transactions in the data?
#
# Make sure they’re sorted from highest to lowest.
#
# Thanks!

# %%
# Read in transactions data -- parse dates specified here for help with later problem

transactions = pd.read_csv("../Agg_&_Reshape_DataFrames/transactions.csv", parse_dates=["date"])

transactions.head()
# Out:
#         date  store_nbr  transactions
# 0 2013-01-01         25           770
# 1 2013-01-02          1          2111
# 2 2013-01-02          2          2358
# 3 2013-01-02          3          3487
# 4 2013-01-02          4          1922

# %%
transactions.groupby('store_nbr')[['transactions']].sum().sort_values('transactions', ascending=False).iloc[:10]
# Out:
#            transactions
# store_nbr
# 44              7273093
# 47              6535810
# 45              6201115
# 46              5990113
# 3               5366350
# 48              5107785
# 8               4637971
# 49              4574103
# 50              4384444
# 11              3972488

# %% [markdown]
# # Assignment 2: Groupby Multiple Columns
#
# Can you get me the total transactions by store and month?
#
# Sort the table from first month to last, then by highest transactions to lowest within each month.

# %%
# helper code to extract month date part from date column

transactions["month"] = transactions["date"].dt.month

transactions
# Out:
#             date  store_nbr  transactions  month
# 0     2013-01-01         25           770      1
# 1     2013-01-02          1          2111      1
# 2     2013-01-02          2          2358      1
# 3     2013-01-02          3          3487      1
# 4     2013-01-02          4          1922      1
# ...          ...        ...           ...    ...
# 83483 2017-08-15         50          2804      8
# 83484 2017-08-15         51          1573      8
# 83485 2017-08-15         52          2255      8
# 83486 2017-08-15         53           932      8
# 83487 2017-08-15         54           802      8
#
# [83488 rows x 4 columns]

# %%
(transactions.groupby(['store_nbr', 'month'])[['transactions']]
 .sum()
 .sort_values(by=['month', 'transactions'], ascending=[True, False]))
# Out:
#                  transactions
# store_nbr month
# 44        1            628438
# 47        1            568824
# 45        1            538370
# 46        1            522763
# 3         1            463260
# ...                       ...
# 32        12            86167
# 21        12            84128
# 42        12            76741
# 29        12            76627
# 22        12            50650
#
# [641 rows x 1 columns]

# %% [markdown]
# # Assignment 3: Multi-Index DataFrames
#
#
# Can you help me access rows and columns with multiple indices? I’ve been struggling with multi-index DataFrames.
#
# Access:
# * Grab Store 3, Month 1
# * Then, select the column storing the mean of transactions
#
# Fix:
# * Drop the outer layer of the column Index
# * Reset the row index so it is the default integer index

# %%
# Ross' grouped DataFrame code, run this first

grouped = (
    transactions.groupby(["store_nbr", "month"])
    .agg({"transactions": ["sum", "mean"]})
    .sort_values(by=["month", ("transactions", "sum")], ascending=[True, False])
)

# %%
# df grouped by store and month with two aggregation columns

grouped.head()
# Out:
#                 transactions
#                          sum         mean
# store_nbr month
# 44        1           628438  4246.202703
# 47        1           568824  3843.405405
# 45        1           538370  3637.635135
# 46        1           522763  3532.182432
# 3         1           463260  3151.428571

# %%
grouped.loc[(43, 1)] # grab with loc
# Out:
# transactions  sum     188657.000000
#               mean      1274.709459
# Name: (43, 1), dtype: float64

# %%
grouped.iloc[4] # grab with iloc
# Out:
# transactions  sum     463260.000000
#               mean      3151.428571
# Name: (3, 1), dtype: float64

# %%
grouped.loc[:, ("transactions", "mean")].head(1)
# Out:
# store_nbr  month
# 44         1        4246.202703
# Name: (transactions, mean), dtype: float64

# %%
grouped.droplevel(0, axis=1).reset_index().head()
# Out:
#    store_nbr  month     sum         mean
# 0         44      1  628438  4246.202703
# 1         47      1  568824  3843.405405
# 2         45      1  538370  3637.635135
# 3         46      1  522763  3532.182432
# 4          3      1  463260  3151.428571

# %% [markdown]
# # Assignment 4: The Agg Method
#
# Calculate the mean of target met by store, and the sum of bonuses to be paid to each store.
#
# Sort them by highest to lowest bonus payout.
#
# Then, do the same for day of week and month.

# %%
# Recreate table from section 3

transactions = transactions.assign(
    target_pct=transactions["transactions"] / 2500,
    met_target=(transactions["transactions"] / 2500) >= 1,
    bonus_payable=((transactions["transactions"] / 2500) >= 1) * 100,
    month=transactions.date.dt.month,
    day_of_week=transactions.date.dt.dayofweek,
)

transactions.head()
# Out:
#         date  store_nbr  transactions  month  target_pct  met_target  \
# 0 2013-01-01         25           770      1      0.3080       False
# 1 2013-01-02          1          2111      1      0.8444       False
# 2 2013-01-02          2          2358      1      0.9432       False
# 3 2013-01-02          3          3487      1      1.3948        True
# 4 2013-01-02          4          1922      1      0.7688       False
#
#    bonus_payable  day_of_week
# 0              0            1
# 1              0            2
# 2              0            2
# 3            100            2
# 4              0            2

# %%
(transactions
 .groupby(["store_nbr"])
 .agg({"met_target": ["mean"],
       "bonus_payable": ["sum"]})
 .sort_values(by=[("met_target", "mean")], ascending=False)
).head(5)
# Out:
#           met_target bonus_payable
#                 mean           sum
# store_nbr
# 47          0.999404        167600
# 44          0.998807        167500
# 3           0.998210        167300
# 45          0.997615        167300
# 46          0.989267        165900

# %%
(transactions
 .groupby(["month"])
 .agg({"met_target": ["mean"],
       "bonus_payable": ["sum"]})
 .sort_values(by=[("met_target", "mean")], ascending=False)
).head(5)
# Out:
#       met_target bonus_payable
#             mean           sum
# month
# 12      0.255640        154100
# 4       0.174469        129700
# 2       0.174230        121700
# 8       0.174189        120800
# 5       0.170792        131800

# %%
(transactions
 .groupby(["day_of_week"])
 .agg({"met_target": ["mean"],
       "bonus_payable": ["sum"]})
 .sort_values(by=[("met_target", "mean")], ascending=False)
).head(5)
# Out:
#             met_target bonus_payable
#                   mean           sum
# day_of_week
# 5             0.222204        266400
# 6             0.204001        241700
# 4             0.179007        213000
# 2             0.160572        191000
# 0             0.160214        191600

# %% [markdown]
# # Assignment 4: Transform
#
# Calculate the mean of transactions by store number and day of week while keeping row numbers.
#
# Then compare the performance of each row to its day of week average. (difference between transactions and daily avg)

# %%
transactions
# Out:
#             date  store_nbr  transactions  month  target_pct  met_target  \
# 0     2013-01-01         25           770      1      0.3080       False
# 1     2013-01-02          1          2111      1      0.8444       False
# 2     2013-01-02          2          2358      1      0.9432       False
# 3     2013-01-02          3          3487      1      1.3948        True
# 4     2013-01-02          4          1922      1      0.7688       False
# ...          ...        ...           ...    ...         ...         ...
# 83483 2017-08-15         50          2804      8      1.1216        True
# 83484 2017-08-15         51          1573      8      0.6292       False
# 83485 2017-08-15         52          2255      8      0.9020       False
# 83486 2017-08-15         53           932      8      0.3728       False
# 83487 2017-08-15         54           802      8      0.3208       False
#
#        bonus_payable  day_of_week
# 0                  0            1
# 1                  0            2
# 2                  0            2
# 3                100            2
# 4                  0            2
# ...              ...          ...
# 83483            100            1
# 83484              0            1
# 83485              0            1
# 83486              0            1
# 83487              0            1
#
# [83488 rows x 8 columns]

# %%
transactions.assign(
    store_avg_trans = (transactions
                    .groupby(["store_nbr", "day_of_week"])
                    ["transactions"]
                    .transform("mean")),
    difference = lambda x: x["transactions"] - x["store_avg_trans"]               
)
# Out:
#             date  store_nbr  transactions  month  target_pct  met_target  \
# 0     2013-01-01         25           770      1      0.3080       False
# 1     2013-01-02          1          2111      1      0.8444       False
# 2     2013-01-02          2          2358      1      0.9432       False
# 3     2013-01-02          3          3487      1      1.3948        True
# 4     2013-01-02          4          1922      1      0.7688       False
# ...          ...        ...           ...    ...         ...         ...
# 83483 2017-08-15         50          2804      8      1.1216        True
# 83484 2017-08-15         51          1573      8      0.6292       False
# 83485 2017-08-15         52          2255      8      0.9020       False
# 83486 2017-08-15         53           932      8      0.3728       False
# 83487 2017-08-15         54           802      8      0.3208       False
#
#        bonus_payable  day_of_week  store_avg_trans  difference
# 0                  0            1       740.245690   29.754310
# 1                  0            2      1870.782427  240.217573
# 2                  0            2      1952.652720  405.347280
# 3                100            2      3142.682008  344.317992
# 4                  0            2      1499.569038  422.430962
# ...              ...          ...              ...         ...
# 83483            100            1      2342.410788  461.589212
# 83484              0            1      1548.448133   24.551867
# 83485              0            1      1892.588235  362.411765
# 83486              0            1       877.214286   54.785714
# 83487              0            1       817.721992  -15.721992
#
# [83488 rows x 10 columns]

# %%
transactions.query("store_nbr == 25").groupby(["day_of_week"]).agg({"transactions" : "mean"})
# Out:
#              transactions
# day_of_week
# 0              808.830435
# 1              740.245690
# 2              849.978261
# 3              800.818182
# 4             1102.817391
# 5             1376.090517
# 6              909.604348

# %% [markdown]
# # Assignment 5: Pivot
#
# Pivot transactions with store number as index, columns day of week, with the sum of bonus payable as cells.
#
# Filter to stores that had a non-zero bonus payable and create a heatmap.
#
# Then unpivot (melt) the table so we have one row for each store and day of the week with the corresponding total owed.

# %%
# Use transactions table (ok if includes columns from assignment 4 or not)

transactions.head()
# Out:
#         date  store_nbr  transactions  month  target_pct  met_target  \
# 0 2013-01-01         25           770      1      0.3080       False
# 1 2013-01-02          1          2111      1      0.8444       False
# 2 2013-01-02          2          2358      1      0.9432       False
# 3 2013-01-02          3          3487      1      1.3948        True
# 4 2013-01-02          4          1922      1      0.7688       False
#
#    bonus_payable  day_of_week
# 0              0            1
# 1              0            2
# 2              0            2
# 3            100            2
# 4              0            2

# %%
transactions.query('bonus_payable != 0').pivot_table(index='store_nbr',
                         columns='day_of_week',
                         values='bonus_payable',
                         aggfunc='sum').head(10).style.background_gradient(cmap="RdYlGn", axis=1)
# Out:
# <style type="text/css">
# #T_17115_row0_col0, #T_17115_row0_col3, #T_17115_row1_col3, #T_17115_row1_col4, #T_17115_row3_col0, #T_17115_row3_col3, #T_17115_row3_col5, #T_17115_row4_col0, #T_17115_row6_col0, #T_17115_row6_col3 {
#   background-color: #feffbe;
#   color: #000000;
# }
# #T_17115_row0_col1, #T_17115_row0_col2, #T_17115_row1_col1, #T_17115_row2_col0, #T_17115_row2_col5, #T_17115_row3_col1, #T_17115_row3_col2, #T_17115_row4_col1, #T_17115_row4_col2, #T_17115_row5_col5, #T_17115_row6_col1, #T_17115_row6_col2, #T_17115_row7_col2, #T_17115_row8_col5, #T_17115_row9_col6 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_17115_row0_col4, #T_17115_row1_col6, #T_17115_row2_col6, #T_17115_row3_col4, #T_17115_row4_col3, #T_17115_row4_col4, #T_17115_row4_col5, #T_17115_row5_col4, #T_17115_row6_col4, #T_17115_row6_col5, #T_17115_row7_col3, #T_17115_row8_col4, #T_17115_row9_col4 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_17115_row0_col5, #T_17115_row0_col6, #T_17115_row3_col6, #T_17115_row4_col6, #T_17115_row6_col6 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_17115_row1_col0 {
#   background-color: #f98e52;
#   color: #f1f1f1;
# }
# #T_17115_row1_col2, #T_17115_row1_col5 {
#   background-color: #84ca66;
#   color: #000000;
# }
# #T_17115_row2_col1, #T_17115_row2_col2, #T_17115_row2_col3, #T_17115_row2_col4 {
#   background-color: #b7e075;
#   color: #000000;
# }
# #T_17115_row5_col0 {
#   background-color: #fca55d;
#   color: #000000;
# }
# #T_17115_row5_col1, #T_17115_row5_col2 {
#   background-color: #fee999;
#   color: #000000;
# }
# #T_17115_row5_col3, #T_17115_row5_col6 {
#   background-color: #e34933;
#   color: #f1f1f1;
# }
# #T_17115_row7_col0 {
#   background-color: #abdb6d;
#   color: #000000;
# }
# #T_17115_row7_col1 {
#   background-color: #e24731;
#   color: #f1f1f1;
# }
# #T_17115_row7_col4 {
#   background-color: #42ac5a;
#   color: #f1f1f1;
# }
# #T_17115_row7_col5 {
#   background-color: #118848;
#   color: #f1f1f1;
# }
# #T_17115_row7_col6 {
#   background-color: #fdc574;
#   color: #000000;
# }
# #T_17115_row8_col0 {
#   background-color: #d93429;
#   color: #f1f1f1;
# }
# #T_17115_row8_col1, #T_17115_row8_col2 {
#   background-color: #be1827;
#   color: #f1f1f1;
# }
# #T_17115_row8_col3 {
#   background-color: #b91326;
#   color: #f1f1f1;
# }
# #T_17115_row8_col6 {
#   background-color: #cbe982;
#   color: #000000;
# }
# #T_17115_row9_col0 {
#   background-color: #d42d27;
#   color: #f1f1f1;
# }
# #T_17115_row9_col1 {
#   background-color: #ed5f3c;
#   color: #f1f1f1;
# }
# #T_17115_row9_col2 {
#   background-color: #ca2427;
#   color: #f1f1f1;
# }
# #T_17115_row9_col3 {
#   background-color: #c41e27;
#   color: #f1f1f1;
# }
# #T_17115_row9_col5 {
#   background-color: #2da155;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_17115">
#   <thead>
#     <tr>
#       <th class="index_name level0" >day_of_week</th>
#       <th id="T_17115_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_17115_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_17115_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_17115_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_17115_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_17115_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_17115_level0_col6" class="col_heading level0 col6" >6</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >store_nbr</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_17115_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_17115_row0_col0" class="data row0 col0" >200.000000</td>
#       <td id="T_17115_row0_col1" class="data row0 col1" >300.000000</td>
#       <td id="T_17115_row0_col2" class="data row0 col2" >300.000000</td>
#       <td id="T_17115_row0_col3" class="data row0 col3" >200.000000</td>
#       <td id="T_17115_row0_col4" class="data row0 col4" >100.000000</td>
#       <td id="T_17115_row0_col5" class="data row0 col5" >nan</td>
#       <td id="T_17115_row0_col6" class="data row0 col6" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_17115_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_17115_row1_col0" class="data row1 col0" >300.000000</td>
#       <td id="T_17115_row1_col1" class="data row1 col1" >600.000000</td>
#       <td id="T_17115_row1_col2" class="data row1 col2" >500.000000</td>
#       <td id="T_17115_row1_col3" class="data row1 col3" >400.000000</td>
#       <td id="T_17115_row1_col4" class="data row1 col4" >400.000000</td>
#       <td id="T_17115_row1_col5" class="data row1 col5" >500.000000</td>
#       <td id="T_17115_row1_col6" class="data row1 col6" >200.000000</td>
#     </tr>
#     <tr>
#       <th id="T_17115_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_17115_row2_col0" class="data row2 col0" >24000.000000</td>
#       <td id="T_17115_row2_col1" class="data row2 col1" >23900.000000</td>
#       <td id="T_17115_row2_col2" class="data row2 col2" >23900.000000</td>
#       <td id="T_17115_row2_col3" class="data row2 col3" >23900.000000</td>
#       <td id="T_17115_row2_col4" class="data row2 col4" >23900.000000</td>
#       <td id="T_17115_row2_col5" class="data row2 col5" >24000.000000</td>
#       <td id="T_17115_row2_col6" class="data row2 col6" >23700.000000</td>
#     </tr>
#     <tr>
#       <th id="T_17115_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_17115_row3_col0" class="data row3 col0" >200.000000</td>
#       <td id="T_17115_row3_col1" class="data row3 col1" >300.000000</td>
#       <td id="T_17115_row3_col2" class="data row3 col2" >300.000000</td>
#       <td id="T_17115_row3_col3" class="data row3 col3" >200.000000</td>
#       <td id="T_17115_row3_col4" class="data row3 col4" >100.000000</td>
#       <td id="T_17115_row3_col5" class="data row3 col5" >200.000000</td>
#       <td id="T_17115_row3_col6" class="data row3 col6" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_17115_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_17115_row4_col0" class="data row4 col0" >200.000000</td>
#       <td id="T_17115_row4_col1" class="data row4 col1" >300.000000</td>
#       <td id="T_17115_row4_col2" class="data row4 col2" >300.000000</td>
#       <td id="T_17115_row4_col3" class="data row4 col3" >100.000000</td>
#       <td id="T_17115_row4_col4" class="data row4 col4" >100.000000</td>
#       <td id="T_17115_row4_col5" class="data row4 col5" >100.000000</td>
#       <td id="T_17115_row4_col6" class="data row4 col6" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_17115_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_17115_row5_col0" class="data row5 col0" >400.000000</td>
#       <td id="T_17115_row5_col1" class="data row5 col1" >500.000000</td>
#       <td id="T_17115_row5_col2" class="data row5 col2" >500.000000</td>
#       <td id="T_17115_row5_col3" class="data row5 col3" >300.000000</td>
#       <td id="T_17115_row5_col4" class="data row5 col4" >200.000000</td>
#       <td id="T_17115_row5_col5" class="data row5 col5" >900.000000</td>
#       <td id="T_17115_row5_col6" class="data row5 col6" >300.000000</td>
#     </tr>
#     <tr>
#       <th id="T_17115_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_17115_row6_col0" class="data row6 col0" >200.000000</td>
#       <td id="T_17115_row6_col1" class="data row6 col1" >300.000000</td>
#       <td id="T_17115_row6_col2" class="data row6 col2" >300.000000</td>
#       <td id="T_17115_row6_col3" class="data row6 col3" >200.000000</td>
#       <td id="T_17115_row6_col4" class="data row6 col4" >100.000000</td>
#       <td id="T_17115_row6_col5" class="data row6 col5" >100.000000</td>
#       <td id="T_17115_row6_col6" class="data row6 col6" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_17115_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_17115_row7_col0" class="data row7 col0

# %%
transactions.query('bonus_payable != 0').pivot_table(index='store_nbr',
                         columns='day_of_week',
                         values='bonus_payable',
                         aggfunc='sum').reset_index().melt(id_vars= "store_nbr",
                                                           value_name= "bonus_payable")
# Out:
#      store_nbr day_of_week  bonus_payable
# 0            1           0          200.0
# 1            2           0          300.0
# 2            3           0        24000.0
# 3            4           0          200.0
# 4            5           0          200.0
# ..         ...         ...            ...
# 240         49           6        21600.0
# 241         50           6        23200.0
# 242         51           6          200.0
# 243         52           6         1500.0
# 244         53           6            NaN
#
# [245 rows x 3 columns]
