# %% [markdown]
# # The Agg Method
# ### The .agg() method lets you perform multiple aggregations on a "groupby" object

# %%
import numpy as np
import pandas as pd

# %%
retail = pd.read_csv("../Agg_&_Reshape_DataFrames/retail_2016_2017.csv")
retail
# Out:
#               id        date  store_nbr                      family     sales  \
# 0        1945944  2016-01-01          1                  AUTOMOTIVE     0.000
# 1        1945945  2016-01-01          1                   BABY CARE     0.000
# 2        1945946  2016-01-01          1                      BEAUTY     0.000
# 3        1945947  2016-01-01          1                   BEVERAGES     0.000
# 4        1945948  2016-01-01          1                       BOOKS     0.000
# ...          ...         ...        ...                         ...       ...
# 1054939  3000883  2017-08-15          9                     POULTRY   438.133
# 1054940  3000884  2017-08-15          9              PREPARED FOODS   154.553
# 1054941  3000885  2017-08-15          9                     PRODUCE  2419.729
# 1054942  3000886  2017-08-15          9  SCHOOL AND OFFICE SUPPLIES   121.000
# 1054943  3000887  2017-08-15          9                     SEAFOOD    16.000
#
#          onpromotion
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# ...              ...
# 1054939            0
# 1054940            1
# 1054941          148
# 1054942            8
# 1054943            0
#
# [1054944 rows x 6 columns]

# %%
# we're dropping columns here to remove object datatypes we cant perform these calculations on
retail.drop(['date', 'id'], axis=1).groupby(['family', 'store_nbr']).agg(['sum', 'mean'])
# Out:
#                              sales            onpromotion
#                                sum       mean         sum      mean
# family     store_nbr
# AUTOMOTIVE 1           2524.000000   4.263514          14  0.023649
#            2           3918.000000   6.618243          12  0.020270
#            3           6790.000000  11.469595          12  0.020270
#            4           2565.000000   4.332770           9  0.015203
#            5           3667.000000   6.194257          17  0.028716
# ...                            ...        ...         ...       ...
# SEAFOOD    50         12773.966999  21.577647         716  1.209459
#            51         34250.948976  57.856333         859  1.451014
#            52          1219.475999   2.059926          78  0.131757
#            53          3745.180001   6.326318         456  0.770270
#            54          1082.000000   1.827703         125  0.211149
#
# [1782 rows x 4 columns]

# %% [markdown]
# # Multiple Aggregations
# ### You can perfiorm a specific aggregation by column by passing a dictionary with column names as keys, and list of aggregation functions as values

# %%
# sales and on promotion are our column names and also our keys. min and max are our values
(retail.groupby(['family', 'store_nbr']).agg({
    'sales': ['sum', 'mean'],
    'onpromotion': ['min', 'max']
})
)
# Out:
#                              sales            onpromotion
#                                sum       mean         min max
# family     store_nbr
# AUTOMOTIVE 1           2524.000000   4.263514           0   1
#            2           3918.000000   6.618243           0   1
#            3           6790.000000  11.469595           0   1
#            4           2565.000000   4.332770           0   1
#            5           3667.000000   6.194257           0   2
# ...                            ...        ...         ...  ..
# SEAFOOD    50         12773.966999  21.577647           0   7
#            51         34250.948976  57.856333           0   7
#            52          1219.475999   2.059926           0   5
#            53          3745.180001   6.326318           0   5
#            54          1082.000000   1.827703           0   2
#
# [1782 rows x 4 columns]

# %% [markdown]
# # Named Aggregations
# ### You can name aggregated columns upon creation to avoid multi-index columns

# %%
# Specify the new column name and assign it a tuple 
# with the column you want to aggregate and the aggregation to perform
(retail
 .groupby(['family', 'store_nbr'])
 .agg(sales_sum=('sales', 'sum'),
      sales_avg=('sales', 'mean'),
      on_promotion_max=('onpromotion', 'max'))
 )
# Out:
#                          sales_sum  sales_avg  on_promotion_max
# family     store_nbr
# AUTOMOTIVE 1           2524.000000   4.263514                 1
#            2           3918.000000   6.618243                 1
#            3           6790.000000  11.469595                 1
#            4           2565.000000   4.332770                 1
#            5           3667.000000   6.194257                 2
# ...                            ...        ...               ...
# SEAFOOD    50         12773.966999  21.577647                 7
#            51         34250.948976  57.856333                 7
#            52          1219.475999   2.059926                 5
#            53          3745.180001   6.326318                 5
#            54          1082.000000   1.827703                 2
#
# [1782 rows x 3 columns]

# %% [markdown]
# ### More examples

# %%
premier_league_full = pd.read_excel("../Agg_&_Reshape_DataFrames/premier_league_games_full.xlsx")
premier_league_full.head()
# Out:
#      id             league_name     season           HomeTeam  \
# 0  1729  England Premier League  2008/2009  Manchester United
# 1  1730  England Premier League  2008/2009            Arsenal
# 2  1731  England Premier League  2008/2009         Sunderland
# 3  1732  England Premier League  2008/2009    West Ham United
# 4  1733  England Premier League  2008/2009        Aston Villa
#
#                AwayTeam  HomeGoals  AwayGoals
# 0      Newcastle United          1          1
# 1  West Bromwich Albion          1          0
# 2             Liverpool          0          1
# 3        Wigan Athletic          2          1
# 4       Manchester City          4          2

# %%
premier_league_full.drop(["league_name", "AwayTeam"], axis=1, inplace=True)
premier_league_full.head()
# Out:
#      id     season           HomeTeam  HomeGoals  AwayGoals
# 0  1729  2008/2009  Manchester United          1          1
# 1  1730  2008/2009            Arsenal          1          0
# 2  1731  2008/2009         Sunderland          0          1
# 3  1732  2008/2009    West Ham United          2          1
# 4  1733  2008/2009        Aston Villa          4          2

# %%
# regular aggregation menthod
(premier_league_full
 .groupby(["season", "HomeTeam"], as_index=False)
 .agg(["sum", "mean"]).round(2)
 )
# Out:
#         season              HomeTeam     id          HomeGoals        \
#                                         sum     mean       sum  mean
# 0    2008/2009               Arsenal  36128  1901.47        31  1.63
# 1    2008/2009           Aston Villa  36136  1901.89        27  1.42
# 2    2008/2009      Blackburn Rovers  36781  1935.84        22  1.16
# 3    2008/2009      Bolton Wanderers  36214  1906.00        21  1.11
# 4    2008/2009               Chelsea  36552  1923.79        33  1.74
# ..         ...                   ...    ...      ...       ...   ...
# 155  2015/2016          Swansea City  87241  4591.63        20  1.05
# 156  2015/2016     Tottenham Hotspur  87218  4590.42        35  1.84
# 157  2015/2016               Watford  87142  4586.42        20  1.05
# 158  2015/2016  West Bromwich Albion  87064  4582.32        20  1.05
# 159  2015/2016       West Ham United  86965  4577.11        34  1.79
#
#     AwayGoals
#           sum  mean
# 0          16  0.84
# 1          21  1.11
# 2          23  1.21
# 3          21  1.11
# 4          12  0.63
# ..        ...   ...
# 155        20  1.05
# 156        15  0.79
# 157        19  1.00
# 158        26  1.37
# 159        26  1.37
#
# [160 rows x 8 columns]

# %%
# mutli aggregation method with a dictionary
(premier_league_full
 .groupby(["season", "HomeTeam"], as_index=False)
 .agg({"HomeGoals" : ["sum", "mean"],
       "AwayGoals" : ["sum", "mean"]})
 )
# Out:
#         season              HomeTeam HomeGoals           AwayGoals
#                                            sum      mean       sum      mean
# 0    2008/2009               Arsenal        31  1.631579        16  0.842105
# 1    2008/2009           Aston Villa        27  1.421053        21  1.105263
# 2    2008/2009      Blackburn Rovers        22  1.157895        23  1.210526
# 3    2008/2009      Bolton Wanderers        21  1.105263        21  1.105263
# 4    2008/2009               Chelsea        33  1.736842        12  0.631579
# ..         ...                   ...       ...       ...       ...       ...
# 155  2015/2016          Swansea City        20  1.052632        20  1.052632
# 156  2015/2016     Tottenham Hotspur        35  1.842105        15  0.789474
# 157  2015/2016               Watford        20  1.052632        19  1.000000
# 158  2015/2016  West Bromwich Albion        20  1.052632        26  1.368421
# 159  2015/2016       West Ham United        34  1.789474        26  1.368421
#
# [160 rows x 6 columns]

# %%
# Named Aggregatioon
(premier_league_full
 .groupby(["season", "HomeTeam"], as_index=False)
 .agg(home_goal_sum=("HomeGoals", "sum"),
      away_goal_sum=("AwayGoals", "sum"))
)
# Out:
#         season              HomeTeam  home_goal_sum  away_goal_sum
# 0    2008/2009               Arsenal             31             16
# 1    2008/2009           Aston Villa             27             21
# 2    2008/2009      Blackburn Rovers             22             23
# 3    2008/2009      Bolton Wanderers             21             21
# 4    2008/2009               Chelsea             33             12
# ..         ...                   ...            ...            ...
# 155  2015/2016          Swansea City             20             20
# 156  2015/2016     Tottenham Hotspur             35             15
# 157  2015/2016               Watford             20             19
# 158  2015/2016  West Bromwich Albion             20             26
# 159  2015/2016       West Ham United             34             26
#
# [160 rows x 4 columns]
