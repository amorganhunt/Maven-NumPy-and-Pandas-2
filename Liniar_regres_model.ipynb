# %% [markdown]
# ## Step 1: Install Necessary Libraries
# ### First, ensure you have scikit-learn installed. If not, you can install it using pip:

# %%
'''

# !pip install scikit-learn
# !pip install matplotlib
# !pip install pandas

'''
# Out:
# '\n\n!pip install scikit-learn\n!pip install matplotlib\n!pip install pandas\n\n'

# %% [markdown]
# ## Step 2: Import Libraries
# ### Import the necessary libraries: numpy for numerical operations, pandas for data handling, matplotlib for plotting, and scikit-learn for the regression model.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# # Step 3: Load the Dataset
# ### For this example, let's use a simple dataset. We'll create a synthetic dataset for demonstration purposes.

# %%
# Creating a synthetic dataset
data = {
    'YearsExperience': [1.1, 2.0, 3.2, 4.5, 5.9, 7.1, 8.0, 9.5, 10.3, 11.2],
    'Salary': [39343, 46205, 56642, 61111, 67938, 66029, 83088, 93940, 101302, 113812]
}
df = pd.DataFrame(data)

# %% [markdown]
# ## Step 4: Explore the Dataset
# ### Let's take a look at the first few rows of the dataset.

# %%
df.head()
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              2.0   46205
# 2              3.2   56642
# 3              4.5   61111
# 4              5.9   67938

# %% [markdown]
# ## Step 5: Visualize the Data
# ### Visualize the data to understand the relationship between the variables.

# %%
plt.scatter(df['YearsExperience'], df['Salary'], color='blue')
plt.title('Years of Experience vs Salary')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# ## Step 6: Split the Data
# ### Split the data into training and testing sets.

# %%
X = df[['YearsExperience']]  # Independent variable
Y = df['Salary']  # Dependent variable

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %% [markdown]
# ## Step 7: Train the Model
# ### Train the linear regression model on the training data.

# %%
model = LinearRegression()
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## Step 8: Make Predictions
# ### Use the trained model to make predictions on the test data.

# %%
Y_pred = model.predict(X_test)
print(Y_pred)
# Out:
# [99776.10107126 43495.90636494]

# %% [markdown]
# ## Step 9: Evaluate the Model
# ### Evaluate the performance of the model using metrics such as Mean Squared Error (MSE) and R-squared.

# %%
mse = mean_squared_error(Y_test, Y_pred)
r2 = r2_score(Y_test, Y_pred)

print('Mean Squared Error:', mse)
print('R-squared:', r2)
# Out:
# Mean Squared Error: 4833777.932134128
# R-squared: 0.9936307135492592

# %% [markdown]
# ## Step 10: Visualize the Results
# ### Visualize the regression line on the training data and the predictions on the test data.

# %%
# Plotting the regression line on the training data
plt.scatter(X_train, Y_train, color='blue')
plt.plot(X_train, model.predict(X_train), color='red')
plt.title('Years of Experience vs Salary (Training set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()

# Plotting the predictions on the test data
plt.scatter(X_test, Y_test, color='blue')
plt.plot(X_test, Y_pred, color='red')
plt.title('Years of Experience vs Salary (Test set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()
